# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Datos\2015_Street_Tree_Census_-_Tree_Data_20231128.csv')
df
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_16084\439445975.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Datos\2015_Street_Tree_Census_-_Tree_Data_20231128.csv')
#                                tree_id  block_id  created_at  tree_dbh  \
# 0                               180683  348711.0  08/27/2015       3.0
# 1                               200540  315986.0  09/03/2015      21.0
# 2                               204026  218365.0  09/05/2015       3.0
# 3                               204337  217969.0  09/05/2015      10.0
# 4                               189565  223043.0  08/30/2015      21.0
# ...                                ...       ...         ...       ...
# 595587                           87087  502292.0  07/22/2015       4.0
# 595588                  "error" : true       NaN         NaN       NaN
# 595589    "message" : "Internal error"       NaN         NaN       NaN
# ...

# %%
data = df[['tree_id', 'block_id', 'tree_dbh', 'stump_diam',
        'status', 'health', 'spc_latin', 'steward',
       'guards', 'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other', ]]
data
# Out:
#                                tree_id  block_id  tree_dbh  stump_diam status  \
# 0                               180683  348711.0       3.0         0.0  Alive
# 1                               200540  315986.0      21.0         0.0  Alive
# 2                               204026  218365.0       3.0         0.0  Alive
# 3                               204337  217969.0      10.0         0.0  Alive
# 4                               189565  223043.0      21.0         0.0  Alive
# ...                                ...       ...       ...         ...    ...
# 595587                           87087  502292.0       4.0         0.0  Alive
# 595588                  "error" : true       NaN       NaN         NaN    NaN
# 595589    "message" : "Internal error"       NaN       NaN         NaN    NaN
# 595590                  "status" : 500       NaN       NaN         NaN    NaN
# 595591                               }       NaN       NaN         NaN    NaN
#
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                                tree_id  block_id  tree_dbh  stump_diam status  \
# 0                               180683  348711.0       3.0         0.0  Alive
# 1                               200540  315986.0      21.0         0.0  Alive
# 2                               204026  218365.0       3.0         0.0  Alive
# 3                               204337  217969.0      10.0         0.0  Alive
# 4                               189565  223043.0      21.0         0.0  Alive
# ...                                ...       ...       ...         ...    ...
# 595587                           87087  502292.0       4.0         0.0  Alive
# 595588                  "error" : true       NaN       NaN         NaN    NaN
# 595589    "message" : "Internal error"       NaN       NaN         NaN    NaN
# 595590                  "status" : 500       NaN       NaN         NaN    NaN
# 595591                               }       NaN       NaN         NaN    NaN
#
# ...

# %%
df = df[pd.to_numeric(df['tree_id'], errors='coerce').notnull()]
df
# Out:
#        tree_id  block_id  tree_dbh  stump_diam status health  \
# 0       180683  348711.0       3.0         0.0  Alive   Fair
# 1       200540  315986.0      21.0         0.0  Alive   Fair
# 2       204026  218365.0       3.0         0.0  Alive   Good
# 3       204337  217969.0      10.0         0.0  Alive   Good
# 4       189565  223043.0      21.0         0.0  Alive   Good
# ...        ...       ...       ...         ...    ...    ...
# 595583  109232  221029.0      20.0         0.0  Alive   Good
# 595584  104803  324842.0      20.0         0.0  Alive   Good
# 595585   94509  109576.0       9.0         0.0  Alive   Good
# 595586   53044  103507.0       5.0         0.0  Alive   Good
# 595587   87087  502292.0       4.0         0.0  Alive   Good
#
#                                  spc_latin steward   guards  sidewalk  \
# 0                              Acer rubrum     NaN      NaN  NoDamage
# 1                        Quercus palustris     NaN      NaN    Damage
# ...

# %%
df.isna().sum()
# Out:
# tree_id            0
# block_id           0
# tree_dbh           0
# stump_diam         0
# status             0
# health         27546
# spc_latin      27547
# steward       460446
# guards        532640
# sidewalk       27547
# problems      405446
# root_stone         1
# root_grate         1
# root_other         1
# trunk_wire         1
# trnk_light         1
# trnk_other         1
# brch_light         1
# brch_shoe          1
# brch_other         1
# dtype: int64

# %%
df.dropna()
# Out:
#        tree_id  block_id  tree_dbh  stump_diam status health  \
# 13      189465  219493.0      22.0         0.0  Alive   Good
# 19      208201  219258.0      10.0         0.0  Alive   Good
# 21      193310  107600.0      14.0         0.0  Alive   Good
# 26      192942  310298.0      33.0         0.0  Alive   Good
# 32      187056  106107.0       7.0         0.0  Alive   Good
# ...        ...       ...       ...         ...    ...    ...
# 595552   96311  226389.0      22.0         0.0  Alive   Good
# 595567  100276  216948.0      12.0         0.0  Alive   Good
# 595569   94673  344858.0      12.0         0.0  Alive   Good
# 595580  100391  224204.0      15.0         0.0  Alive   Good
# 595583  109232  221029.0      20.0         0.0  Alive   Good
#
#                                  spc_latin steward   guards  sidewalk  \
# 13                   Platanus x acerifolia    3or4  Harmful  NoDamage
# 19                           Ginkgo biloba    1or2  Helpful  NoDamage
# ...

# %%
df = df.dropna()
df
# Out:
#        tree_id  block_id  tree_dbh  stump_diam status health  \
# 13      189465  219493.0      22.0         0.0  Alive   Good
# 19      208201  219258.0      10.0         0.0  Alive   Good
# 21      193310  107600.0      14.0         0.0  Alive   Good
# 26      192942  310298.0      33.0         0.0  Alive   Good
# 32      187056  106107.0       7.0         0.0  Alive   Good
# ...        ...       ...       ...         ...    ...    ...
# 595552   96311  226389.0      22.0         0.0  Alive   Good
# 595567  100276  216948.0      12.0         0.0  Alive   Good
# 595569   94673  344858.0      12.0         0.0  Alive   Good
# 595580  100391  224204.0      15.0         0.0  Alive   Good
# 595583  109232  221029.0      20.0         0.0  Alive   Good
#
#                                  spc_latin steward   guards  sidewalk  \
# 13                   Platanus x acerifolia    3or4  Harmful  NoDamage
# 19                           Ginkgo biloba    1or2  Helpful  NoDamage
# ...

# %%
x = stump_t = df['stump_diam'] > 0
stump_t = x.sum()

# %%
y = df['stump_diam'] == 0
stump_f = y.sum()

# %%
total = stump_f + stump_t

# %%
print('Number of stumps', stump_t)
print('Number of trees (dead/alive)', stump_f)
print('Total', total)
# Out:
# Number of stumps 0
# Number of trees (dead/alive) 16776
# Total 16776

# %%
alive_trees = df['status'] == 'Alive'
a_t = alive_trees.sum()

# %%
print('Alive trees:', a_t)
# Out:
# Alive trees: 16776

# %% [markdown]
# Now that we saw every trees are alive and no one is a stump, we can delete this column

# %%
df.drop(columns = 'stump_diam')
# Out:
#        tree_id  block_id  tree_dbh status health  \
# 13      189465  219493.0      22.0  Alive   Good
# 19      208201  219258.0      10.0  Alive   Good
# 21      193310  107600.0      14.0  Alive   Good
# 26      192942  310298.0      33.0  Alive   Good
# 32      187056  106107.0       7.0  Alive   Good
# ...        ...       ...       ...    ...    ...
# 595552   96311  226389.0      22.0  Alive   Good
# 595567  100276  216948.0      12.0  Alive   Good
# 595569   94673  344858.0      12.0  Alive   Good
# 595580  100391  224204.0      15.0  Alive   Good
# 595583  109232  221029.0      20.0  Alive   Good
#
#                                  spc_latin steward   guards  sidewalk  \
# 13                   Platanus x acerifolia    3or4  Harmful  NoDamage
# 19                           Ginkgo biloba    1or2  Helpful  NoDamage
# 21      Gleditsia triacanthos var. inermis    1or2   Unsure    Damage
# 26                   Platanus x acerifolia    1or2  Helpful  NoDamage
# ...

# %%
df = df.drop(columns = 'stump_diam')
df
# Out:
#        tree_id  block_id  tree_dbh status health  \
# 13      189465  219493.0      22.0  Alive   Good
# 19      208201  219258.0      10.0  Alive   Good
# 21      193310  107600.0      14.0  Alive   Good
# 26      192942  310298.0      33.0  Alive   Good
# 32      187056  106107.0       7.0  Alive   Good
# ...        ...       ...       ...    ...    ...
# 595552   96311  226389.0      22.0  Alive   Good
# 595567  100276  216948.0      12.0  Alive   Good
# 595569   94673  344858.0      12.0  Alive   Good
# 595580  100391  224204.0      15.0  Alive   Good
# 595583  109232  221029.0      20.0  Alive   Good
#
#                                  spc_latin steward   guards  sidewalk  \
# 13                   Platanus x acerifolia    3or4  Harmful  NoDamage
# 19                           Ginkgo biloba    1or2  Helpful  NoDamage
# 21      Gleditsia triacanthos var. inermis    1or2   Unsure    Damage
# 26                   Platanus x acerifolia    1or2  Helpful  NoDamage
# ...

# %%
df.drop(columns = 'status')
# Out:
#        tree_id  block_id  tree_dbh health                           spc_latin  \
# 13      189465  219493.0      22.0   Good               Platanus x acerifolia
# 19      208201  219258.0      10.0   Good                       Ginkgo biloba
# 21      193310  107600.0      14.0   Good  Gleditsia triacanthos var. inermis
# 26      192942  310298.0      33.0   Good               Platanus x acerifolia
# 32      187056  106107.0       7.0   Good  Gleditsia triacanthos var. inermis
# ...        ...       ...       ...    ...                                 ...
# 595552   96311  226389.0      22.0   Good               Platanus x acerifolia
# 595567  100276  216948.0      12.0   Good  Gleditsia triacanthos var. inermis
# 595569   94673  344858.0      12.0   Good                     Ulmus americana
# 595580  100391  224204.0      15.0   Good               Platanus x acerifolia
# 595583  109232  221029.0      20.0   Good               Platanus x acerifolia
#
# ...

# %%
df = df.drop(columns = 'status')
df
# Out:
#        tree_id  block_id  tree_dbh health                           spc_latin  \
# 13      189465  219493.0      22.0   Good               Platanus x acerifolia
# 19      208201  219258.0      10.0   Good                       Ginkgo biloba
# 21      193310  107600.0      14.0   Good  Gleditsia triacanthos var. inermis
# 26      192942  310298.0      33.0   Good               Platanus x acerifolia
# 32      187056  106107.0       7.0   Good  Gleditsia triacanthos var. inermis
# ...        ...       ...       ...    ...                                 ...
# 595552   96311  226389.0      22.0   Good               Platanus x acerifolia
# 595567  100276  216948.0      12.0   Good  Gleditsia triacanthos var. inermis
# 595569   94673  344858.0      12.0   Good                     Ulmus americana
# 595580  100391  224204.0      15.0   Good               Platanus x acerifolia
# 595583  109232  221029.0      20.0   Good               Platanus x acerifolia
#
# ...

# %%
df['health'] != 'Good'
# Out:
# 13        False
# 19        False
# 21        False
# 26        False
# 32        False
#           ...
# 595552    False
# 595567    False
# 595569    False
# 595580    False
# 595583    False
# Name: health, Length: 16776, dtype: bool

# %%
df.drop(columns = 'health')
# Out:
#        tree_id  block_id  tree_dbh                           spc_latin  \
# 13      189465  219493.0      22.0               Platanus x acerifolia
# 19      208201  219258.0      10.0                       Ginkgo biloba
# 21      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 26      192942  310298.0      33.0               Platanus x acerifolia
# 32      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...        ...       ...       ...                                 ...
# 595552   96311  226389.0      22.0               Platanus x acerifolia
# 595567  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 595569   94673  344858.0      12.0                     Ulmus americana
# 595580  100391  224204.0      15.0               Platanus x acerifolia
# 595583  109232  221029.0      20.0               Platanus x acerifolia
#
#        steward   guards  sidewalk                          problems  \
# ...

# %%
df = df.drop(columns = 'health')
df
# Out:
#        tree_id  block_id  tree_dbh                           spc_latin  \
# 13      189465  219493.0      22.0               Platanus x acerifolia
# 19      208201  219258.0      10.0                       Ginkgo biloba
# 21      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 26      192942  310298.0      33.0               Platanus x acerifolia
# 32      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...        ...       ...       ...                                 ...
# 595552   96311  226389.0      22.0               Platanus x acerifolia
# 595567  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 595569   94673  344858.0      12.0                     Ulmus americana
# 595580  100391  224204.0      15.0               Platanus x acerifolia
# 595583  109232  221029.0      20.0               Platanus x acerifolia
#
#        steward   guards  sidewalk                          problems  \
# ...

# %%
df.drop(columns = 'steward')
# Out:
#        tree_id  block_id  tree_dbh                           spc_latin  \
# 13      189465  219493.0      22.0               Platanus x acerifolia
# 19      208201  219258.0      10.0                       Ginkgo biloba
# 21      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 26      192942  310298.0      33.0               Platanus x acerifolia
# 32      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...        ...       ...       ...                                 ...
# 595552   96311  226389.0      22.0               Platanus x acerifolia
# 595567  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 595569   94673  344858.0      12.0                     Ulmus americana
# 595580  100391  224204.0      15.0               Platanus x acerifolia
# 595583  109232  221029.0      20.0               Platanus x acerifolia
#
#          guards  sidewalk                          problems root_stone  \
# ...

# %%
df = df.drop(columns = 'steward')
df
# Out:
#        tree_id  block_id  tree_dbh                           spc_latin  \
# 13      189465  219493.0      22.0               Platanus x acerifolia
# 19      208201  219258.0      10.0                       Ginkgo biloba
# 21      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 26      192942  310298.0      33.0               Platanus x acerifolia
# 32      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...        ...       ...       ...                                 ...
# 595552   96311  226389.0      22.0               Platanus x acerifolia
# 595567  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 595569   94673  344858.0      12.0                     Ulmus americana
# 595580  100391  224204.0      15.0               Platanus x acerifolia
# 595583  109232  221029.0      20.0               Platanus x acerifolia
#
#          guards  sidewalk                          problems root_stone  \
# ...

# %%
df.drop(columns = 'sidewalk')
# Out:
#        tree_id  block_id  tree_dbh                           spc_latin  \
# 13      189465  219493.0      22.0               Platanus x acerifolia
# 19      208201  219258.0      10.0                       Ginkgo biloba
# 21      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 26      192942  310298.0      33.0               Platanus x acerifolia
# 32      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...        ...       ...       ...                                 ...
# 595552   96311  226389.0      22.0               Platanus x acerifolia
# 595567  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 595569   94673  344858.0      12.0                     Ulmus americana
# 595580  100391  224204.0      15.0               Platanus x acerifolia
# 595583  109232  221029.0      20.0               Platanus x acerifolia
#
#          guards                          problems root_stone root_grate  \
# ...

# %%
df = df.drop(columns = 'sidewalk')
df
# Out:
#        tree_id  block_id  tree_dbh                           spc_latin  \
# 13      189465  219493.0      22.0               Platanus x acerifolia
# 19      208201  219258.0      10.0                       Ginkgo biloba
# 21      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 26      192942  310298.0      33.0               Platanus x acerifolia
# 32      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...        ...       ...       ...                                 ...
# 595552   96311  226389.0      22.0               Platanus x acerifolia
# 595567  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 595569   94673  344858.0      12.0                     Ulmus americana
# 595580  100391  224204.0      15.0               Platanus x acerifolia
# 595583  109232  221029.0      20.0               Platanus x acerifolia
#
#          guards                          problems root_stone root_grate  \
# ...

# %%
df.columns
# Out:
# Index(['tree_id', 'block_id', 'tree_dbh', 'spc_latin', 'guards', 'problems',
#        'root_stone', 'root_grate', 'root_other', 'trunk_wire', 'trnk_light',
#        'trnk_other', 'brch_light', 'brch_shoe', 'brch_other'],
#       dtype='object')

# %%
data_f =df[['tree_id', 'block_id', 'tree_dbh', 'spc_latin', 'guards', 'problems']]
data_f
# Out:
#        tree_id  block_id  tree_dbh                           spc_latin  \
# 13      189465  219493.0      22.0               Platanus x acerifolia
# 19      208201  219258.0      10.0                       Ginkgo biloba
# 21      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 26      192942  310298.0      33.0               Platanus x acerifolia
# 32      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...        ...       ...       ...                                 ...
# 595552   96311  226389.0      22.0               Platanus x acerifolia
# 595567  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 595569   94673  344858.0      12.0                     Ulmus americana
# 595580  100391  224204.0      15.0               Platanus x acerifolia
# 595583  109232  221029.0      20.0               Platanus x acerifolia
#
#          guards                          problems
# 13      Harmful                         RootOther
# ...

# %%
df = pd.DataFrame(data_f)
df
# Out:
#        tree_id  block_id  tree_dbh                           spc_latin  \
# 13      189465  219493.0      22.0               Platanus x acerifolia
# 19      208201  219258.0      10.0                       Ginkgo biloba
# 21      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 26      192942  310298.0      33.0               Platanus x acerifolia
# 32      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...        ...       ...       ...                                 ...
# 595552   96311  226389.0      22.0               Platanus x acerifolia
# 595567  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 595569   94673  344858.0      12.0                     Ulmus americana
# 595580  100391  224204.0      15.0               Platanus x acerifolia
# 595583  109232  221029.0      20.0               Platanus x acerifolia
#
#          guards                          problems
# 13      Harmful                         RootOther
# ...

# %%
df.reset_index(drop=True)
# Out:
#       tree_id  block_id  tree_dbh                           spc_latin  \
# 0      189465  219493.0      22.0               Platanus x acerifolia
# 1      208201  219258.0      10.0                       Ginkgo biloba
# 2      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 3      192942  310298.0      33.0               Platanus x acerifolia
# 4      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...       ...       ...       ...                                 ...
# 16771   96311  226389.0      22.0               Platanus x acerifolia
# 16772  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 16773   94673  344858.0      12.0                     Ulmus americana
# 16774  100391  224204.0      15.0               Platanus x acerifolia
# 16775  109232  221029.0      20.0               Platanus x acerifolia
#
#         guards                          problems
# 0      Harmful                         RootOther
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#       tree_id  block_id  tree_dbh                           spc_latin  \
# 0      189465  219493.0      22.0               Platanus x acerifolia
# 1      208201  219258.0      10.0                       Ginkgo biloba
# 2      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 3      192942  310298.0      33.0               Platanus x acerifolia
# 4      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...       ...       ...       ...                                 ...
# 16771   96311  226389.0      22.0               Platanus x acerifolia
# 16772  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 16773   94673  344858.0      12.0                     Ulmus americana
# 16774  100391  224204.0      15.0               Platanus x acerifolia
# 16775  109232  221029.0      20.0               Platanus x acerifolia
#
#         guards                          problems
# 0      Harmful                         RootOther
# ...

# %%
df['problems'].str.replace(',', '/')
# Out:
# 0                               RootOther
# 1                                  Stones
# 2        RootOther/TrunkOther/BranchOther
# 3                     Stones/BranchLights
# 4                  MetalGrates/TrunkOther
#                        ...
# 16771                         BranchOther
# 16772                    Stones/WiresRope
# 16773       Stones/RootOther/BranchLights
# 16774                 Stones/BranchLights
# 16775                           WiresRope
# Name: problems, Length: 16776, dtype: object

# %%
df['problems'] = df['problems'].str.replace(',', '/')
df
# Out:
#       tree_id  block_id  tree_dbh                           spc_latin  \
# 0      189465  219493.0      22.0               Platanus x acerifolia
# 1      208201  219258.0      10.0                       Ginkgo biloba
# 2      193310  107600.0      14.0  Gleditsia triacanthos var. inermis
# 3      192942  310298.0      33.0               Platanus x acerifolia
# 4      187056  106107.0       7.0  Gleditsia triacanthos var. inermis
# ...       ...       ...       ...                                 ...
# 16771   96311  226389.0      22.0               Platanus x acerifolia
# 16772  100276  216948.0      12.0  Gleditsia triacanthos var. inermis
# 16773   94673  344858.0      12.0                     Ulmus americana
# 16774  100391  224204.0      15.0               Platanus x acerifolia
# 16775  109232  221029.0      20.0               Platanus x acerifolia
#
#         guards                          problems
# 0      Harmful                         RootOther
# ...
