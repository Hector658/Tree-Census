# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Datos\2015_Street_Tree_Census_-_Tree_Data_20231128.csv')
df
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_332\439445975.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Datos\2015_Street_Tree_Census_-_Tree_Data_20231128.csv')
#                                tree_id  block_id  created_at  tree_dbh  \
# 0                               180683  348711.0  08/27/2015       3.0
# 1                               200540  315986.0  09/03/2015      21.0
# 2                               204026  218365.0  09/05/2015       3.0
# 3                               204337  217969.0  09/05/2015      10.0
# 4                               189565  223043.0  08/30/2015      21.0
# ...                                ...       ...         ...       ...
# 595587                           87087  502292.0  07/22/2015       4.0
# 595588                  "error" : true       NaN         NaN       NaN
# 595589    "message" : "Internal error"       NaN         NaN       NaN
# 595590                  "status" : 500       NaN         NaN       NaN
# 595591                               }       NaN         NaN       NaN
#
#         stump_diam curb_loc status health                           spc_latin  \
# 0              0.0   OnCurb  Alive   Fair                         Acer rubrum
# 1              0.0   OnCurb  Alive   Fair                   Quercus palustris
# 2              0.0   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis
# 3              0.0   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis
# 4              0.0   OnCurb  Alive   Good                     Tilia americana
# ...            ...      ...    ...    ...                                 ...
# 595587         0.0   OnCurb  Alive   Good                       Ginkgo biloba
# 595588         NaN      NaN    NaN    NaN                                 NaN
# 595589         NaN      NaN    NaN    NaN                                 NaN
# 595590         NaN      NaN    NaN    NaN                                 NaN
# 595591         NaN      NaN    NaN    NaN                                 NaN
#
#              spc_common  ...    boro_ct     state   latitude  longitude  \
# 0             red maple  ...  4073900.0  New York  40.723092 -73.844215
# 1               pin oak  ...  4097300.0  New York  40.794111 -73.818679
# 2           honeylocust  ...  3044900.0  New York  40.717581 -73.936608
# 3           honeylocust  ...  3044900.0  New York  40.713537 -73.934456
# 4       American linden  ...  3016500.0  New York  40.666778 -73.975979
# ...                 ...  ...        ...       ...        ...        ...
# 595587               g{  ...        NaN       NaN        NaN        NaN
# 595588              NaN  ...        NaN       NaN        NaN        NaN
# 595589              NaN  ...        NaN       NaN        NaN        NaN
# 595590              NaN  ...        NaN       NaN        NaN        NaN
# 595591              NaN  ...        NaN       NaN        NaN        NaN
#
#                x_sp         y_sp council district census tract        bin  \
# 0       1027431.148  202756.7687             29.0        739.0  4052307.0
# 1       1034455.701  228644.8374             19.0        973.0  4101931.0
# 2       1001822.831  200716.8913             34.0        449.0  3338310.0
# 3       1002420.358  199244.2531             34.0        449.0  3338342.0
# 4        990913.775  182202.4260             39.0        165.0  3025654.0
# ...             ...          ...              ...          ...        ...
# 595587          NaN          NaN              NaN          NaN        NaN
# 595588          NaN          NaN              NaN          NaN        NaN
# 595589          NaN          NaN              NaN          NaN        NaN
# 595590          NaN          NaN              NaN          NaN        NaN
# 595591          NaN          NaN              NaN          NaN        NaN
#
#                  bbl
# 0       4.022210e+09
# 1       4.044750e+09
# 2       3.028870e+09
# 3       3.029250e+09
# 4       3.010850e+09
# ...              ...
# 595587           NaN
# 595588           NaN
# 595589           NaN
# 595590           NaN
# 595591           NaN
#
# [595592 rows x 45 columns]

# %%
data = df[['tree_id', 'block_id', 'tree_dbh', 'stump_diam',
        'status', 'health', 'spc_latin', 'steward',
       'guards', 'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other' ]]
data
# Out:
#                                tree_id  block_id  tree_dbh  stump_diam status  \
# 0                               180683  348711.0       3.0         0.0  Alive
# 1                               200540  315986.0      21.0         0.0  Alive
# 2                               204026  218365.0       3.0         0.0  Alive
# 3                               204337  217969.0      10.0         0.0  Alive
# 4                               189565  223043.0      21.0         0.0  Alive
# ...                                ...       ...       ...         ...    ...
# 595587                           87087  502292.0       4.0         0.0  Alive
# 595588                  "error" : true       NaN       NaN         NaN    NaN
# 595589    "message" : "Internal error"       NaN       NaN         NaN    NaN
# 595590                  "status" : 500       NaN       NaN         NaN    NaN
# 595591                               }       NaN       NaN         NaN    NaN
#
#        health                           spc_latin steward guards  sidewalk  \
# 0        Fair                         Acer rubrum     NaN    NaN  NoDamage
# 1        Fair                   Quercus palustris     NaN    NaN    Damage
# 2        Good  Gleditsia triacanthos var. inermis    1or2    NaN    Damage
# 3        Good  Gleditsia triacanthos var. inermis     NaN    NaN    Damage
# 4        Good                     Tilia americana     NaN    NaN    Damage
# ...       ...                                 ...     ...    ...       ...
# 595587   Good                       Ginkgo biloba     NaN    NaN       NaN
# 595588    NaN                                 NaN     NaN    NaN       NaN
# 595589    NaN                                 NaN     NaN    NaN       NaN
# 595590    NaN                                 NaN     NaN    NaN       NaN
# 595591    NaN                                 NaN     NaN    NaN       NaN
#
#        problems root_stone root_grate root_other trunk_wire trnk_light  \
# 0           NaN         No         No         No         No         No
# 1        Stones        Yes         No         No         No         No
# 2           NaN         No         No         No         No         No
# 3        Stones        Yes         No         No         No         No
# 4        Stones        Yes         No         No         No         No
# ...         ...        ...        ...        ...        ...        ...
# 595587      NaN        NaN        NaN        NaN        NaN        NaN
# 595588      NaN        NaN        NaN        NaN        NaN        NaN
# 595589      NaN        NaN        NaN        NaN        NaN        NaN
# 595590      NaN        NaN        NaN        NaN        NaN        NaN
# 595591      NaN        NaN        NaN        NaN        NaN        NaN
#
#        trnk_other brch_light brch_shoe brch_other
# 0              No         No        No         No
# 1              No         No        No         No
# 2              No         No        No         No
# 3              No         No        No         No
# 4              No         No        No         No
# ...           ...        ...       ...        ...
# 595587        NaN        NaN       NaN        NaN
# 595588        NaN        NaN       NaN        NaN
# 595589        NaN        NaN       NaN        NaN
# 595590        NaN        NaN       NaN        NaN
# 595591        NaN        NaN       NaN        NaN
#
# [595592 rows x 20 columns]

# %%
df = pd.DataFrame(data)
df
# Out:
#                                tree_id  block_id  tree_dbh  stump_diam status  \
# 0                               180683  348711.0       3.0         0.0  Alive
# 1                               200540  315986.0      21.0         0.0  Alive
# 2                               204026  218365.0       3.0         0.0  Alive
# 3                               204337  217969.0      10.0         0.0  Alive
# 4                               189565  223043.0      21.0         0.0  Alive
# ...                                ...       ...       ...         ...    ...
# 595587                           87087  502292.0       4.0         0.0  Alive
# 595588                  "error" : true       NaN       NaN         NaN    NaN
# 595589    "message" : "Internal error"       NaN       NaN         NaN    NaN
# 595590                  "status" : 500       NaN       NaN         NaN    NaN
# 595591                               }       NaN       NaN         NaN    NaN
#
#        health                           spc_latin steward guards  sidewalk  \
# 0        Fair                         Acer rubrum     NaN    NaN  NoDamage
# 1        Fair                   Quercus palustris     NaN    NaN    Damage
# 2        Good  Gleditsia triacanthos var. inermis    1or2    NaN    Damage
# 3        Good  Gleditsia triacanthos var. inermis     NaN    NaN    Damage
# 4        Good                     Tilia americana     NaN    NaN    Damage
# ...       ...                                 ...     ...    ...       ...
# 595587   Good                       Ginkgo biloba     NaN    NaN       NaN
# 595588    NaN                                 NaN     NaN    NaN       NaN
# 595589    NaN                                 NaN     NaN    NaN       NaN
# 595590    NaN                                 NaN     NaN    NaN       NaN
# 595591    NaN                                 NaN     NaN    NaN       NaN
#
#        problems root_stone root_grate root_other trunk_wire trnk_light  \
# 0           NaN         No         No         No         No         No
# 1        Stones        Yes         No         No         No         No
# 2           NaN         No         No         No         No         No
# 3        Stones        Yes         No         No         No         No
# 4        Stones        Yes         No         No         No         No
# ...         ...        ...        ...        ...        ...        ...
# 595587      NaN        NaN        NaN        NaN        NaN        NaN
# 595588      NaN        NaN        NaN        NaN        NaN        NaN
# 595589      NaN        NaN        NaN        NaN        NaN        NaN
# 595590      NaN        NaN        NaN        NaN        NaN        NaN
# 595591      NaN        NaN        NaN        NaN        NaN        NaN
#
#        trnk_other brch_light brch_shoe brch_other
# 0              No         No        No         No
# 1              No         No        No         No
# 2              No         No        No         No
# 3              No         No        No         No
# 4              No         No        No         No
# ...           ...        ...       ...        ...
# 595587        NaN        NaN       NaN        NaN
# 595588        NaN        NaN       NaN        NaN
# 595589        NaN        NaN       NaN        NaN
# 595590        NaN        NaN       NaN        NaN
# 595591        NaN        NaN       NaN        NaN
#
# [595592 rows x 20 columns]

# %%
df = df[pd.to_numeric(df['tree_id'], errors='coerce').notnull()]
df.head(13)
# Out:
#    tree_id  block_id  tree_dbh  stump_diam status health  \
# 0   180683  348711.0       3.0         0.0  Alive   Fair
# 1   200540  315986.0      21.0         0.0  Alive   Fair
# 2   204026  218365.0       3.0         0.0  Alive   Good
# 3   204337  217969.0      10.0         0.0  Alive   Good
# 4   189565  223043.0      21.0         0.0  Alive   Good
# 5   190422  106099.0      11.0         0.0  Alive   Good
# 6   190426  106099.0      11.0         0.0  Alive   Good
# 7   208649  103940.0       9.0         0.0  Alive   Good
# 8   209610  407443.0       6.0         0.0  Alive   Good
# 9   192755  207508.0      21.0         0.0  Alive   Fair
# 10  203719  302371.0      11.0         0.0  Alive   Good
# 11  203726  302371.0       8.0         0.0  Alive   Poor
# 12  195202  415896.0      13.0         0.0  Alive   Fair
#
#                              spc_latin steward   guards  sidewalk  \
# 0                          Acer rubrum     NaN      NaN  NoDamage
# 1                    Quercus palustris     NaN      NaN    Damage
# 2   Gleditsia triacanthos var. inermis    1or2      NaN    Damage
# 3   Gleditsia triacanthos var. inermis     NaN      NaN    Damage
# 4                      Tilia americana     NaN      NaN    Damage
# 5   Gleditsia triacanthos var. inermis    1or2  Helpful  NoDamage
# 6   Gleditsia triacanthos var. inermis    1or2  Helpful  NoDamage
# 7                      Tilia americana     NaN      NaN  NoDamage
# 8   Gleditsia triacanthos var. inermis     NaN      NaN  NoDamage
# 9                Platanus x acerifolia     NaN      NaN  NoDamage
# 10               Platanus x acerifolia     NaN      NaN  NoDamage
# 11               Platanus x acerifolia     NaN      NaN  NoDamage
# 12               Platanus x acerifolia     NaN      NaN  NoDamage
#
#        problems root_stone root_grate root_other trunk_wire trnk_light  \
# 0           NaN         No         No         No         No         No
# 1        Stones        Yes         No         No         No         No
# 2           NaN         No         No         No         No         No
# 3        Stones        Yes         No         No         No         No
# 4        Stones        Yes         No         No         No         No
# 5           NaN         No         No         No         No         No
# 6           NaN         No         No         No         No         No
# 7   MetalGrates         No        Yes         No         No         No
# 8           NaN         No         No         No         No         No
# 9           NaN         No         No         No         No         No
# 10          NaN         No         No         No         No         No
# 11          NaN         No         No         No         No         No
# 12       Stones        Yes         No         No         No         No
#
#    trnk_other brch_light brch_shoe brch_other
# 0          No         No        No         No
# 1          No         No        No         No
# 2          No         No        No         No
# 3          No         No        No         No
# 4          No         No        No         No
# 5          No         No        No         No
# 6          No         No        No         No
# 7          No         No        No         No
# 8          No         No        No         No
# 9          No         No        No         No
# 10         No         No        No         No
# 11         No         No        No         No
# 12         No         No        No         No

# %%
df.isna().sum()
# Out:
# tree_id            0
# block_id           0
# tree_dbh           0
# stump_diam         0
# status             0
# health         27546
# spc_latin      27547
# steward       460446
# guards        532640
# sidewalk       27547
# problems      405446
# root_stone         1
# root_grate         1
# root_other         1
# trunk_wire         1
# trnk_light         1
# trnk_other         1
# brch_light         1
# brch_shoe          1
# brch_other         1
# dtype: int64

# %%
dead_trees = df[(df['health'] != 'Fair') & (df['health'] != 'Good')].index
dead_trees
# Out:
# Index([    11,     37,     57,     73,     85,     88,    140,    158,    175,
#           196,
#        ...
#        595447, 595451, 595491, 595505, 595506, 595518, 595519, 595520, 595568,
#        595582],
#       dtype='int64', length=50135)

# %%
df.drop(dead_trees , inplace=True)
df
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_332\3505300856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(dead_trees , inplace=True)
#        tree_id  block_id  tree_dbh  stump_diam status health  \
# 0       180683  348711.0       3.0         0.0  Alive   Fair
# 1       200540  315986.0      21.0         0.0  Alive   Fair
# 2       204026  218365.0       3.0         0.0  Alive   Good
# 3       204337  217969.0      10.0         0.0  Alive   Good
# 4       189565  223043.0      21.0         0.0  Alive   Good
# ...        ...       ...       ...         ...    ...    ...
# 595583  109232  221029.0      20.0         0.0  Alive   Good
# 595584  104803  324842.0      20.0         0.0  Alive   Good
# 595585   94509  109576.0       9.0         0.0  Alive   Good
# 595586   53044  103507.0       5.0         0.0  Alive   Good
# 595587   87087  502292.0       4.0         0.0  Alive   Good
#
#                                  spc_latin steward   guards  sidewalk  \
# 0                              Acer rubrum     NaN      NaN  NoDamage
# 1                        Quercus palustris     NaN      NaN    Damage
# 2       Gleditsia triacanthos var. inermis    1or2      NaN    Damage
# 3       Gleditsia triacanthos var. inermis     NaN      NaN    Damage
# 4                          Tilia americana     NaN      NaN    Damage
# ...                                    ...     ...      ...       ...
# 595583               Platanus x acerifolia    3or4  Helpful  NoDamage
# 595584               Platanus x acerifolia     NaN      NaN  NoDamage
# 595585  Gleditsia triacanthos var. inermis     NaN      NaN  NoDamage
# 595586  Gleditsia triacanthos var. inermis     NaN      NaN  NoDamage
# 595587                       Ginkgo biloba     NaN      NaN       NaN
#
#                    problems root_stone root_grate root_other trunk_wire  \
# 0                       NaN         No         No         No         No
# 1                    Stones        Yes         No         No         No
# 2                       NaN         No         No         No         No
# 3                    Stones        Yes         No         No         No
# 4                    Stones        Yes         No         No         No
# ...                     ...        ...        ...        ...        ...
# 595583            WiresRope         No         No         No        Yes
# 595584                  NaN         No         No         No         No
# 595585  Stones,BranchLights        Yes         No         No         No
# 595586                  NaN         No         No         No         No
# 595587                  NaN        NaN        NaN        NaN        NaN
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 0              No         No         No        No         No
# 1              No         No         No        No         No
# 2              No         No         No        No         No
# 3              No         No         No        No         No
# 4              No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 595583         No         No         No        No         No
# 595584         No         No         No        No         No
# 595585         No         No        Yes        No         No
# 595586         No         No         No        No         No
# 595587        NaN        NaN        NaN       NaN        NaN
#
# [545453 rows x 20 columns]

# %%
df.isna().sum()
# Out:
# tree_id            0
# block_id           0
# tree_dbh           0
# stump_diam         0
# status             0
# health             0
# spc_latin          2
# steward       415917
# guards        485311
# sidewalk           2
# problems      364737
# root_stone         1
# root_grate         1
# root_other         1
# trunk_wire         1
# trnk_light         1
# trnk_other         1
# brch_light         1
# brch_shoe          1
# brch_other         1
# dtype: int64

# %%
df[df['spc_latin'].isna()]
# Out:
#        tree_id  block_id  tree_dbh  stump_diam status health spc_latin  \
# 356613  562532  315837.0       4.0         0.0  Alive   Good       NaN
# 431417  651014  308540.0      40.0         0.0  Alive   Good       NaN
#
#        steward guards  sidewalk problems root_stone root_grate root_other  \
# 356613    1or2    NaN  NoDamage   Stones        Yes         No         No
# 431417     NaN    NaN    Damage   Stones        Yes         No         No
#
#        trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other
# 356613         No         No         No         No        No         No
# 431417         No         No         No         No        No         No

# %%
df['spc_latin'].fillna('Unknown')
# Out:
# 0                                Acer rubrum
# 1                          Quercus palustris
# 2         Gleditsia triacanthos var. inermis
# 3         Gleditsia triacanthos var. inermis
# 4                            Tilia americana
#                          ...
# 595583                 Platanus x acerifolia
# 595584                 Platanus x acerifolia
# 595585    Gleditsia triacanthos var. inermis
# 595586    Gleditsia triacanthos var. inermis
# 595587                         Ginkgo biloba
# Name: spc_latin, Length: 545453, dtype: object

# %%
df['spc_latin'] = df['spc_latin'].fillna('Unknown')
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_332\3892242485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spc_latin'] = df['spc_latin'].fillna('Unknown')

# %%
no_name = df.loc[df['spc_latin'] == 'Unknown']
no_name
# Out:
#        tree_id  block_id  tree_dbh  stump_diam status health spc_latin  \
# 356613  562532  315837.0       4.0         0.0  Alive   Good   Unknown
# 431417  651014  308540.0      40.0         0.0  Alive   Good   Unknown
#
#        steward guards  sidewalk problems root_stone root_grate root_other  \
# 356613    1or2    NaN  NoDamage   Stones        Yes         No         No
# 431417     NaN    NaN    Damage   Stones        Yes         No         No
#
#        trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other
# 356613         No         No         No         No        No         No
# 431417         No         No         No         No        No         No

# %%
df.isna().sum()
# Out:
# tree_id            0
# block_id           0
# tree_dbh           0
# stump_diam         0
# status             0
# health             0
# spc_latin          0
# steward       415917
# guards        485311
# sidewalk           2
# problems      364737
# root_stone         1
# root_grate         1
# root_other         1
# trunk_wire         1
# trnk_light         1
# trnk_other         1
# brch_light         1
# brch_shoe          1
# brch_other         1
# dtype: int64

# %%
h_guards = df['guards'] == 'Helpful'
B_guards = df['guards'] == 'Harmful'
u_guards = df['guards'] == 'Unsure'
h_gh = h_guards.sum()
b_g = B_guards.sum()
u_gh = u_guards.sum()

# %%
total_g = h_gh + B_guards + u_gh
print('The number of helpful guards is', h_gh, '\t harmful', b_g, '\t and unsure guards', u_gh, '\t')
print('For a total of: \t ', total_g)
# Out:
# The number of helpful guards is 39494 	 harmful 14699 	 and unsure guards 5949
# For a total of: 	  0         45443
# 1         45443
# 2         45443
# 3         45443
# 4         45443
#           ...
# 595583    45443
# 595584    45443
# 595585    45443
# 595586    45443
# 595587    45443
# Name: guards, Length: 545453, dtype: int64

# %%
df['guards'] = df['guards'].fillna('No Guards')
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_332\1794891937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['guards'] = df['guards'].fillna('No Guards')

# %%
df.drop(['steward', 'sidewalk'], axis=1)
# Out:
#        tree_id  block_id  tree_dbh  stump_diam status health  \
# 0       180683  348711.0       3.0         0.0  Alive   Fair
# 1       200540  315986.0      21.0         0.0  Alive   Fair
# 2       204026  218365.0       3.0         0.0  Alive   Good
# 3       204337  217969.0      10.0         0.0  Alive   Good
# 4       189565  223043.0      21.0         0.0  Alive   Good
# ...        ...       ...       ...         ...    ...    ...
# 595583  109232  221029.0      20.0         0.0  Alive   Good
# 595584  104803  324842.0      20.0         0.0  Alive   Good
# 595585   94509  109576.0       9.0         0.0  Alive   Good
# 595586   53044  103507.0       5.0         0.0  Alive   Good
# 595587   87087  502292.0       4.0         0.0  Alive   Good
#
#                                  spc_latin     guards             problems  \
# 0                              Acer rubrum  No Guards                  NaN
# 1                        Quercus palustris  No Guards               Stones
# 2       Gleditsia triacanthos var. inermis  No Guards                  NaN
# 3       Gleditsia triacanthos var. inermis  No Guards               Stones
# 4                          Tilia americana  No Guards               Stones
# ...                                    ...        ...                  ...
# 595583               Platanus x acerifolia    Helpful            WiresRope
# 595584               Platanus x acerifolia  No Guards                  NaN
# 595585  Gleditsia triacanthos var. inermis  No Guards  Stones,BranchLights
# 595586  Gleditsia triacanthos var. inermis  No Guards                  NaN
# 595587                       Ginkgo biloba  No Guards                  NaN
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 595583         No         No         No        Yes         No         No
# 595584         No         No         No         No         No         No
# 595585        Yes         No         No         No         No         No
# 595586         No         No         No         No         No         No
# 595587        NaN        NaN        NaN        NaN        NaN        NaN
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# 1              No        No         No
# 2              No        No         No
# 3              No        No         No
# 4              No        No         No
# ...           ...       ...        ...
# 595583         No        No         No
# 595584         No        No         No
# 595585        Yes        No         No
# 595586         No        No         No
# 595587        NaN       NaN        NaN
#
# [545453 rows x 18 columns]

# %%
df = df.drop(['steward', 'sidewalk'], axis=1)
df.head(3)
# Out:
#   tree_id  block_id  tree_dbh  stump_diam status health  \
# 0  180683  348711.0       3.0         0.0  Alive   Fair
# 1  200540  315986.0      21.0         0.0  Alive   Fair
# 2  204026  218365.0       3.0         0.0  Alive   Good
#
#                             spc_latin     guards problems root_stone  \
# 0                         Acer rubrum  No Guards      NaN         No
# 1                   Quercus palustris  No Guards   Stones        Yes
# 2  Gleditsia triacanthos var. inermis  No Guards      NaN         No
#
#   root_grate root_other trunk_wire trnk_light trnk_other brch_light brch_shoe  \
# 0         No         No         No         No         No         No        No
# 1         No         No         No         No         No         No        No
# 2         No         No         No         No         No         No        No
#
#   brch_other
# 0         No
# 1         No
# 2         No

# %%
df.drop(['root_stone', 'root_grate', 'root_other', 'trunk_wire', 'trnk_light',
        'trnk_other', 'brch_light', 'brch_shoe', 'brch_other'], axis=1)
# Out:
#        tree_id  block_id  tree_dbh  stump_diam status health  \
# 0       180683  348711.0       3.0         0.0  Alive   Fair
# 1       200540  315986.0      21.0         0.0  Alive   Fair
# 2       204026  218365.0       3.0         0.0  Alive   Good
# 3       204337  217969.0      10.0         0.0  Alive   Good
# 4       189565  223043.0      21.0         0.0  Alive   Good
# ...        ...       ...       ...         ...    ...    ...
# 595583  109232  221029.0      20.0         0.0  Alive   Good
# 595584  104803  324842.0      20.0         0.0  Alive   Good
# 595585   94509  109576.0       9.0         0.0  Alive   Good
# 595586   53044  103507.0       5.0         0.0  Alive   Good
# 595587   87087  502292.0       4.0         0.0  Alive   Good
#
#                                  spc_latin     guards             problems
# 0                              Acer rubrum  No Guards                  NaN
# 1                        Quercus palustris  No Guards               Stones
# 2       Gleditsia triacanthos var. inermis  No Guards                  NaN
# 3       Gleditsia triacanthos var. inermis  No Guards               Stones
# 4                          Tilia americana  No Guards               Stones
# ...                                    ...        ...                  ...
# 595583               Platanus x acerifolia    Helpful            WiresRope
# 595584               Platanus x acerifolia  No Guards                  NaN
# 595585  Gleditsia triacanthos var. inermis  No Guards  Stones,BranchLights
# 595586  Gleditsia triacanthos var. inermis  No Guards                  NaN
# 595587                       Ginkgo biloba  No Guards                  NaN
#
# [545453 rows x 9 columns]

# %%
df = df.drop(['root_stone', 'root_grate', 'root_other', 'trunk_wire', 'trnk_light',
        'trnk_other', 'brch_light', 'brch_shoe', 'brch_other'], axis=1)
df.head(3)
# Out:
#   tree_id  block_id  tree_dbh  stump_diam status health  \
# 0  180683  348711.0       3.0         0.0  Alive   Fair
# 1  200540  315986.0      21.0         0.0  Alive   Fair
# 2  204026  218365.0       3.0         0.0  Alive   Good
#
#                             spc_latin     guards problems
# 0                         Acer rubrum  No Guards      NaN
# 1                   Quercus palustris  No Guards   Stones
# 2  Gleditsia triacanthos var. inermis  No Guards      NaN

# %%
df.isna().sum()
# Out:
# tree_id            0
# block_id           0
# tree_dbh           0
# stump_diam         0
# status             0
# health             0
# spc_latin          0
# guards             0
# problems      364737
# dtype: int64

# %%
df['problems'] = df['problems'].fillna('No Problems')
df
# Out:
#        tree_id  block_id  tree_dbh  stump_diam status health  \
# 0       180683  348711.0       3.0         0.0  Alive   Fair
# 1       200540  315986.0      21.0         0.0  Alive   Fair
# 2       204026  218365.0       3.0         0.0  Alive   Good
# 3       204337  217969.0      10.0         0.0  Alive   Good
# 4       189565  223043.0      21.0         0.0  Alive   Good
# ...        ...       ...       ...         ...    ...    ...
# 595583  109232  221029.0      20.0         0.0  Alive   Good
# 595584  104803  324842.0      20.0         0.0  Alive   Good
# 595585   94509  109576.0       9.0         0.0  Alive   Good
# 595586   53044  103507.0       5.0         0.0  Alive   Good
# 595587   87087  502292.0       4.0         0.0  Alive   Good
#
#                                  spc_latin     guards             problems
# 0                              Acer rubrum  No Guards          No Problems
# 1                        Quercus palustris  No Guards               Stones
# 2       Gleditsia triacanthos var. inermis  No Guards          No Problems
# 3       Gleditsia triacanthos var. inermis  No Guards               Stones
# 4                          Tilia americana  No Guards               Stones
# ...                                    ...        ...                  ...
# 595583               Platanus x acerifolia    Helpful            WiresRope
# 595584               Platanus x acerifolia  No Guards          No Problems
# 595585  Gleditsia triacanthos var. inermis  No Guards  Stones,BranchLights
# 595586  Gleditsia triacanthos var. inermis  No Guards          No Problems
# 595587                       Ginkgo biloba  No Guards          No Problems
#
# [545453 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# tree_id       0
# block_id      0
# tree_dbh      0
# stump_diam    0
# status        0
# health        0
# spc_latin     0
# guards        0
# problems      0
# dtype: int64

# %%
df['problems'] = df['problems'].str.replace(',', '/')

# %%
df
# Out:
#        tree_id  block_id  tree_dbh  stump_diam status health  \
# 0       180683  348711.0       3.0         0.0  Alive   Fair
# 1       200540  315986.0      21.0         0.0  Alive   Fair
# 2       204026  218365.0       3.0         0.0  Alive   Good
# 3       204337  217969.0      10.0         0.0  Alive   Good
# 4       189565  223043.0      21.0         0.0  Alive   Good
# ...        ...       ...       ...         ...    ...    ...
# 595583  109232  221029.0      20.0         0.0  Alive   Good
# 595584  104803  324842.0      20.0         0.0  Alive   Good
# 595585   94509  109576.0       9.0         0.0  Alive   Good
# 595586   53044  103507.0       5.0         0.0  Alive   Good
# 595587   87087  502292.0       4.0         0.0  Alive   Good
#
#                                  spc_latin     guards             problems
# 0                              Acer rubrum  No Guards          No Problems
# 1                        Quercus palustris  No Guards               Stones
# 2       Gleditsia triacanthos var. inermis  No Guards          No Problems
# 3       Gleditsia triacanthos var. inermis  No Guards               Stones
# 4                          Tilia americana  No Guards               Stones
# ...                                    ...        ...                  ...
# 595583               Platanus x acerifolia    Helpful            WiresRope
# 595584               Platanus x acerifolia  No Guards          No Problems
# 595585  Gleditsia triacanthos var. inermis  No Guards  Stones/BranchLights
# 595586  Gleditsia triacanthos var. inermis  No Guards          No Problems
# 595587                       Ginkgo biloba  No Guards          No Problems
#
# [545453 rows x 9 columns]

# %%
df.drop(['status'], axis=1)
# Out:
#        tree_id  block_id  tree_dbh  stump_diam health  \
# 0       180683  348711.0       3.0         0.0   Fair
# 1       200540  315986.0      21.0         0.0   Fair
# 2       204026  218365.0       3.0         0.0   Good
# 3       204337  217969.0      10.0         0.0   Good
# 4       189565  223043.0      21.0         0.0   Good
# ...        ...       ...       ...         ...    ...
# 595583  109232  221029.0      20.0         0.0   Good
# 595584  104803  324842.0      20.0         0.0   Good
# 595585   94509  109576.0       9.0         0.0   Good
# 595586   53044  103507.0       5.0         0.0   Good
# 595587   87087  502292.0       4.0         0.0   Good
#
#                                  spc_latin     guards             problems
# 0                              Acer rubrum  No Guards          No Problems
# 1                        Quercus palustris  No Guards               Stones
# 2       Gleditsia triacanthos var. inermis  No Guards          No Problems
# 3       Gleditsia triacanthos var. inermis  No Guards               Stones
# 4                          Tilia americana  No Guards               Stones
# ...                                    ...        ...                  ...
# 595583               Platanus x acerifolia    Helpful            WiresRope
# 595584               Platanus x acerifolia  No Guards          No Problems
# 595585  Gleditsia triacanthos var. inermis  No Guards  Stones/BranchLights
# 595586  Gleditsia triacanthos var. inermis  No Guards          No Problems
# 595587                       Ginkgo biloba  No Guards          No Problems
#
# [545453 rows x 8 columns]

# %%
df = df.drop(['status'], axis=1)
df
# Out:
#        tree_id  block_id  tree_dbh  stump_diam health  \
# 0       180683  348711.0       3.0         0.0   Fair
# 1       200540  315986.0      21.0         0.0   Fair
# 2       204026  218365.0       3.0         0.0   Good
# 3       204337  217969.0      10.0         0.0   Good
# 4       189565  223043.0      21.0         0.0   Good
# ...        ...       ...       ...         ...    ...
# 595583  109232  221029.0      20.0         0.0   Good
# 595584  104803  324842.0      20.0         0.0   Good
# 595585   94509  109576.0       9.0         0.0   Good
# 595586   53044  103507.0       5.0         0.0   Good
# 595587   87087  502292.0       4.0         0.0   Good
#
#                                  spc_latin     guards             problems
# 0                              Acer rubrum  No Guards          No Problems
# 1                        Quercus palustris  No Guards               Stones
# 2       Gleditsia triacanthos var. inermis  No Guards          No Problems
# 3       Gleditsia triacanthos var. inermis  No Guards               Stones
# 4                          Tilia americana  No Guards               Stones
# ...                                    ...        ...                  ...
# 595583               Platanus x acerifolia    Helpful            WiresRope
# 595584               Platanus x acerifolia  No Guards          No Problems
# 595585  Gleditsia triacanthos var. inermis  No Guards  Stones/BranchLights
# 595586  Gleditsia triacanthos var. inermis  No Guards          No Problems
# 595587                       Ginkgo biloba  No Guards          No Problems
#
# [545453 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# tree_id       0
# block_id      0
# tree_dbh      0
# stump_diam    0
# health        0
# spc_latin     0
# guards        0
# problems      0
# dtype: int64

# %%
pd.DataFrame(df['health'].value_counts()).plot(kind='bar', figsize=(20,10))
# Out:
# <Axes: xlabel='health'>

# %%
pd.DataFrame(df['spc_latin'].value_counts()).plot(kind='bar', figsize=(20,10))
# Out:
# <Axes: xlabel='spc_latin'>
